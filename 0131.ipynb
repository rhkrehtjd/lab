# %% [markdown]
# > ### 제 4강

# %% [markdown]
# - 3rd generation sequencing platform
#   - long read
#   - single molecule
#   - platform
#     - PacBio SMRT
#       - 미생물 유전체와 전장유전체 확보에 많이 사용
#     - Oxford Nanopore
#   - ![image.png](attachment:02934073-7275-4a8a-9ade-fb10484e73c5.png)

# %% [markdown]
# - long read sequencing의 특징
#   - ![image.png](attachment:5c651910-bafb-408f-9365-0834afb6e149.png)
#   - 오류율 해결 <- illumina short read 추가적으로 생산해야함

# %% [markdown]
# - PacBIO sequencing platforms
#   - 단일분자 실시간 시퀀싱
#   - `증폭없이` 시퀀싱 진행
#   - single molecule real time sequencing(SMRT)
#     - ![image.png](attachment:6559559a-ee79-48ae-a4ed-0768de170897.png)
#   - RS 시스템과 Sequel 시스템으로 나눌 수 있음
#   - 두가지의 시퀀싱 모드가 있음
#     - ![image.png](attachment:47ed86ce-e30b-4c76-90ac-0a22609959e9.png)

# %% [markdown]
# - Hi-Fi read
#   - ![image.png](attachment:ac006c6d-9fd7-4987-a784-9eb86675950e.png)

# %% [markdown]
# - oxford nanopore platform
#   - 대표적 예) MinION
#   - long read, but 낮은 정확도
