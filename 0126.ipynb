# %% [markdown]
# > ### 제 4강

# %% [markdown]
# - diversity analysis
#   - ![image.png](attachment:d6ed0383-0cfc-47d3-ac48-9eb00343860e.png)
#   - to compare microbial communities
#   - two types of diversity
#     - alpha diversity
#       - diversity of species within a habitat unit
#       - 피부면 피부, 장이면 장에서 얼마나 많은 종이 있고 각 종마다 얼만큼 있는지!
#       - 한 individual site !!
#       - E.g. Within one human individual oral site; what and how?
#     - beta diversity
#       - diversity between habitats
#       - site들을 비교!
#       - E.g. Between two human individuals; How similar or different?

# %% [markdown]
# - QIIME 2
#   - q2-diversity plugin
#   - ![image.png](attachment:5033175a-8e2b-4558-90c0-b943e9648162.png)
#   - core-metrics-phylogenetic method

# %% [markdown]
# - ![image.png](attachment:63dc97ad-6cd1-45e4-b6ce-44d0141f40a1.png)

# %% [markdown]
# - richness를 보고싶다 -> Shannon's diversity index 확인...

# %% [markdown]
# - core-metrics-phylogenetic method 사용하기 위한 parameter
#   - ![image.png](attachment:d201e841-7996-448d-8e37-64ab48e5b558.png)

# %% [markdown]
# - alpha-group-significance
#   - 그룹 간의 다양성이 차이가 있는지 없는지?
#   - gut의 미생물 종류와 규모, oral의 미생물 종류와 규모를 비교해보고 싶다.
#   - ![image.png](attachment:e1afed89-58d1-4cfd-b8aa-9124b9308ca1.png)
# - beta-group-significance
#   - ![image.png](attachment:d25cda61-acc0-4a02-b705-c06a2c3dfa49.png)
#   - ![image.png](attachment:42a78445-3f1b-4eb2-bb96-987b16b50fb6.png)
#   - 알파랑 다르게 특정 메타데이터컬럼을 지정해주어야 함

# %% [markdown]
# - principal coordinates analysis
#   - ordination
#   - PCoA
#   - PCA(Pricipal conponents analysis), 얘와 비슷하지만,,,,,PCoA는 dissimilarity matrix로부터 차원을 줄인다..?
#   - ![image.png](attachment:96e59493-348d-42d5-b53c-7a71cf9da6a8.png)
