# %% [markdown]
# > ### 제 2강

# %% [markdown]
# - QIIME 2를 설치해보자!
# - QIIME 2의 concepts에 대해 알아보자
# - importing data
# - demultiplexing sequences

# %% [markdown]
# - core concepts of QIIME2
#   - data files : QIIME 2 artifacts(이게 output 형태)
#     - data produced by QIIME 2
#     - contains data and metadata (type, format, and how it was generated; provenance)
#     - file의 확장자는 아래와 같음
#     - ".qza" file extension when stored in a file

# %% [markdown]
# - 위 확장자 말고, ".qzv"라는 확장자도 있음
#   - 분석을 하고 나서 결과를 볼 수 있는 시각화시킨 file이라고 할 수 있음
#   - 그냥 볼 순 없고 별도의 plugin이 필요함
#   - view.qiime2.org에서 보거나
#   - 명령어를 통해 브라우징을 로딩해 볼 수 있음

# %% [markdown]
# - ![image.png](attachment:9552f469-3db6-4e4c-be57-431732aa4262.png)

# %% [markdown]
# - QIIME 2의 공통적인 분석?
#   - what species are present?
#     - Taxonomic classification of sequences
#   - 나의 샘플이 얼마나 다양성을 가지고 있는지 비교
#     - how similar are my samples?
#     - 다양성 분석을 할 때 여러 박테리아간들의 진화적 관계도 ..
#     - 박테리아의 종류뿐만 아니라 sample간의 비교를 통해서 differential abundance measurements도 측정

# %% [markdown]
# ---

# %% [markdown]
# - preparation for the data analysis
#
# ```
# mkdir qiime2-moving-pictures-tutorial
# cd qiime2-moving-pictures-tutorial
# ```

# %% [markdown]
# - obtaining data files-sample metadata
#   - 시퀀싱 raw data를 얻음
#     - 어떤 시퀀싱 데이터가 어떤 정보들을 가지고 있는지 알려주는 metadata도 필요함
#     - 다음의 명령어로 수행 가능
#     - ![image.png](attachment:9af3a053-3ae9-4665-a04b-7360ce73c0fa.png)
#     - -O줄의 명령어는 이 파일의 이름으로 저장해라~
#     - wget~ data를 다운받는 명령어

# %% [markdown]
# - obtaining data files - sequences reads
#   - 실질적으로 시퀀싱 reads 데이터를 얻기 위해서 directory 하나 더 생성
#   - ![image.png](attachment:be68f6a8-bedd-4875-a1e9-82b41c8b50b4.png)
#   - 첫번째 파일 : demultiflexing 단계에서 사용될 파일
#   - 두번째 파일 : 실질적으로 필요한 raw data

# %% [markdown]
# - importing data
#   - to perform analysis in QIIME2, QIIME 2 artifacts should be generated from the sequence data
#   - ![image.png](attachment:556682a6-8ff0-4d9d-ae21-8c3393001913.png)

# %% [markdown]
# - 지금가진 raw sequences를 얻음

# %% [markdown]
# ------

# %% [markdown]
# - demultiflexsing sequences?
#   - ![image.png](attachment:979e77b1-1f63-45e0-941f-3773e1846ccd.png)
#   - 샘플이 하나면 상관없는데 두개 이상의 샘플인 시퀀싱 데이터를 만들고자 할 때, 여섯개의 샘플이 있다고 하자
#   - 한 샘플당 600만개의 read생산이 가능하지만 그 정도까진 필요없고 백만개정도만 필요하다
#   - 그럼 그냥 한 샘플당 백만개씩만 생산하자
#   - A단계에서 1번 샘플과 2번샘플을 서로 다른 바코드로 tagging함
#   - B단계에서 두 샘플을 같이 시퀀싱함(multiplexing 단계임)
#   - raw data 받을 때, 바코드 시퀀싱 정보와 그냥 raw데이터를 같이 받았었음
#     - demultiplexing 할 때 필요함
#   - C -> D 과정이 demultiflexing이라고 함

# %% [markdown]
# - 각각의 샘플에 해당하는 바코드 시퀀스 정보는 처음 받았던 metadata file에 저장돼있음
# - 태깅돼있는 정보들을 이용해서
#   - ![image.png](attachment:4eb3d39d-b26b-4e61-b4ea-c2a3e1210995.png)
#   - qza 파일이 input 파일

# %% [markdown]
# - check the demultiplexing results
#   - ![image.png](attachment:7626f290-f376-4dd0-9b17-9d23157075cd.png)
#   - iuput -> .qza
#   - output -> .qzv

# %% [markdown]
# - 전용 사이트에서 보거나
# - 아니면
# - ![image.png](attachment:ca25872e-0acd-4bf3-9271-0a1540ab8422.png)
